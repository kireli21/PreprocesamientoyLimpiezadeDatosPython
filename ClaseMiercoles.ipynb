# %%
import pandas as pd

# %%
#Descargar el conector de mysql y la lib de llama sqlalchemy

# !pip install mysql-connector-python sqlalchemy
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\kireli\anaconda3\lib\site-packages (8.0.33)
# Requirement already satisfied: sqlalchemy in c:\users\kireli\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in c:\users\kireli\anaconda3\lib\site-packages (from mysql-connector-python) (3.20.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kireli\anaconda3\lib\site-packages (from sqlalchemy) (2.0.1)

# %%
sql = '''SELECT * FROM Alumnos WHERE DATE(fnac) >=  %s'''

df_mysql=pd.read_sql_query(sql = sql, con = conn, params = ['2000-01-01'])

# %%
df_mysql
# Out:
#   no_cuenta  nombre    paterno       fnac  estatura
# 0        1A    Juan      Lopez 2001-01-01      1.78
# 1       1GG   Maria  Paterno 1 2001-03-20      1.60
# 2      21OL   Donna      River 2002-01-09      1.69
# 3       2GG   Maria  Paterno 2 2001-03-20      1.62
# 4        3B   Perla     Calles 2001-01-20      1.60
# 5        4A  Carlos     Madero 2001-01-01      1.68
# 6       574   Pedro  Paterno 5 2022-01-31      1.60
# 7        6C   Jesus     Garcia 2001-03-20      1.65
# 8        7B    Gema       None 2001-03-20      1.53
# 9      A744   Amaro     Garcia 2001-09-23      1.83

# %%
! pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.4.0-cp310-cp310-win_amd64.whl (453 kB)
#      ------------------------------------ 453.6/453.6 kB 945.3 kB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      -------------------------------------- 283.7/283.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.3.0 pymongo-4.4.0

# %%
import pymongo

# %%
usuario = 'fesalu'
passwd = 'nosqlfes123'
cluster = 'cluster0-shard-00-00.8pyt4.mongodb.net'
n1 = 'cluster0-shard-00-01.8pyt4.mongodb.net'
n2 = 'cluster0-shard-00-02.8pyt4.mongodb.net'
puerto = '27017'
mongo_str = f"mongodb://{usuario}:{passwd}@{cluster}:{puerto},{n1}:{puerto},{n2}:{puerto}/?ssl=true&replicaSet=atlas-nok9e6-shard-0&authSource=admin&retryWrites=true&w=majority"
print(mongo_str)
mongoClient = pymongo.MongoClient(mongo_str)
mongoClient
# Out:
# mongodb://fesalu:nosqlfes123@cluster0-shard-00-00.8pyt4.mongodb.net:27017,cluster0-shard-00-01.8pyt4.mongodb.net:27017,cluster0-shard-00-02.8pyt4.mongodb.net:27017/?ssl=true&replicaSet=atlas-nok9e6-shard-0&authSource=admin&retryWrites=true&w=majority
# MongoClient(host=['cluster0-shard-00-02.8pyt4.mongodb.net:27017', 'cluster0-shard-00-01.8pyt4.mongodb.net:27017', 'cluster0-shard-00-00.8pyt4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-nok9e6-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True)

# %%
"ver las bd disponibles"

mongoClient.list_database_names()
# Out:
# ['OmarMendozaGonzalez',
#  'agenda',
#  'colegio',
#  'fundamentosmongo',
#  'itsa',
#  'pdcd',
#  'taller',
#  'tbd',
#  'tebd',
#  'admin',
#  'local']

# %%
db = mongoClient.colegio
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.8pyt4.mongodb.net:27017', 'cluster0-shard-00-01.8pyt4.mongodb.net:27017', 'cluster0-shard-00-00.8pyt4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-nok9e6-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'colegio')

# %%
f = db.alumnos.find({'curp': { '$exists': 0}})
f

# %%
lista_f = list(f)

print(lista_f)
# Out:
# [{'_id': ObjectId('5f873e4a7591b0b48f65faf9'), 'clave_alu': 11030177, 'ap_paterno': 'FERRUSCA', 'ap_materno': 'ANDRADE', 'nombre': 'OCTAVIO', 'sexo': 'M', 'ciudad': 'QUERETARO', 'email': 'tavoferrus_11@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65faf6'), 'clave_alu': 11030172, 'ap_paterno': 'BORBOLLA', 'ap_materno': 'RAMOS', 'nombre': 'ARGELIA', 'sexo': 'F', 'ciudad': 'QUERETARO', 'email': 'kargi_gogos@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fafc'), 'clave_alu': 11030199, 'ap_paterno': 'ROSALES', 'ap_materno': 'APREZA', 'nombre': 'NESTOR MARTIN', 'sexo': 'M', 'ciudad': 'QUERETARO', 'email': 'nestoriwh@hotmai.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb04'), 'clave_alu': 11030217, 'ap_paterno': 'FERRUSCA', 'ap_materno': 'ANDRADE', 'nombre': 'CESAR', 'sexo': 'M', 'ciudad': 'QUERETARO', 'email': 'cesar_tum-b@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fafb'), 'clave_alu': 11030173, 'ap_paterno': 'CASTRO', 'ap_materno': 'MANCERA', 'nombre': 'KARLA MARIANA', 'sexo': 'F', 'ciudad': 'SANTIAGO DE QUERETARO'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb0b'), 'clave_alu': 11030242, 'ap_paterno': 'ALCOCER', 'ap_materno': 'ESCOBAR', 'nombre': 'AGUSTIN', 'sexo': 'M'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb06'), 'clave_alu': 11030232, 'ap_paterno': 'PEREZ', 'ap_materno': 'DEL CASTILLO VELASCO', 'nombre': 'ESTEBAN', 'email': 'estebanlunete@yahoo.com.mx'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb13'), 'clave_alu': 11030273, 'ap_paterno': 'URIBE', 'ap_materno': 'GARCIA', 'nombre': 'MARIA GUADALUPE', 'ciudad': 'QUERETARO', 'email': 'misato227@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb08'), 'clave_alu': 11030235, 'ap_paterno': 'SAAVEDRA', 'ap_materno': 'MARTINEZ', 'nombre': 'GABRIEL ANDRES', 'sexo': 'M', 'ciudad': 'QUERETARO', 'email': 'gasaa_10@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb17'), 'clave_alu': 11030292, 'ap_paterno': 'PEREA', 'ap_materno': 'PACHECO', 'nombre': 'FERNANDO'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb0e'), 'clave_alu': 11030213, 'ap_paterno': 'COSS', 'ap_materno': 'AGUADO', 'nombre': 'RAUL ANDRES', 'ciudad': 'QUERETARO', 'email': 'andrescoss285@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb11'), 'clave_alu': 11030268, 'ap_paterno': 'MONTIEL', 'ap_materno': 'PEREZ', 'nombre': 'CARLOS GABRIEL', 'sexo': 'M', 'ciudad': 'QUERETARO', 'email': 'gabos_1803@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fafe'), 'clave_alu': 11030204, 'ap_paterno': 'VAZQUEZ', 'ap_materno': 'GONZALEZ', 'nombre': 'ROBERTO', 'sexo': 'M', 'ciudad': 'SANTIAGO DE QUERETARO', 'email': 'rob_vaz03@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb1d'), 'clave_alu': 11040003, 'ap_paterno': 'BARRON', 'ap_materno': 'LOEZA', 'nombre': 'GABRIELA', 'sexo': 'F', 'ciudad': 'QUERETARO', 'email': 'gabybalo89@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb21'), 'clave_alu': 11040021, 'ap_paterno': 'HERNANDEZ', 'ap_materno': 'MORENO', 'nombre': 'MARIA JOSE', 'sexo': 'F', 'ciudad': 'QUERETARO', 'email': 'mahemo_10@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb28'), 'clave_alu': 11040046, 'ap_paterno': 'AGUIRRE', 'ap_materno': 'MARGAIN', 'nombre': 'LAURA ALEJANDRA'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb2e'), 'clave_alu': 11040035, 'ap_paterno': 'PEREZ', 'ap_materno': 'RETANA', 'nombre': 'DANIEL', 'sexo': 'M', 'ciudad': 'QUERETARO', 'email': 'oraciones_9@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb30'), 'clave_alu': 11040043, 'ap_paterno': 'VAZQUEZ', 'ap_materno': 'ARTEAGA', 'nombre': 'THALIA IVETTE', 'sexo': 'F'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb33'), 'clave_alu': 11040069, 'ap_paterno': 'MARUSICH', 'ap_materno': 'CASTELLANOS', 'nombre': 'ANDRES', 'sexo': 'M', 'ciudad': 'QUERETARO', 'email': 'marucholey@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb32'), 'clave_alu': 11040044, 'ap_paterno': 'VEGA', 'ap_materno': 'VEGA', 'nombre': 'ELIZABETH', 'ciudad': 'QUERETARO', 'email': 'liznena1@email.com'}, {'_id': ObjectId('5f873e4a7591b0b48f65fb38'), 'clave_alu': 11040074, 'ap_p ...

# %%
df_mongo = pd.DataFrame(lista_f)
df_mongo
# Out:
#                           _id  clave_alu ap_paterno ap_materno         nombre  \
# 0    5f873e4a7591b0b48f65faf9   11030177   FERRUSCA    ANDRADE        OCTAVIO
# 1    5f873e4a7591b0b48f65faf6   11030172   BORBOLLA      RAMOS        ARGELIA
# 2    5f873e4a7591b0b48f65fafc   11030199    ROSALES     APREZA  NESTOR MARTIN
# 3    5f873e4a7591b0b48f65fb04   11030217   FERRUSCA    ANDRADE          CESAR
# 4    5f873e4a7591b0b48f65fafb   11030173     CASTRO    MANCERA  KARLA MARIANA
# ..                        ...        ...        ...        ...            ...
# 197  5f873e4a7591b0b48f65fe1a   14080001      MEJIA    JIMENEZ          LUISA
# 198  5f873e4a7591b0b48f65fe1d   12080001
# 199  5f873e4a7591b0b48f65fe19   14080002      MEJIA    JIMENEZ          LUISA
# 200  5f873e4a7591b0b48f65fe1b   14080003      MEJIA    JIMENEZ          LUISA
# 201  5f873e4a7591b0b48f65fe1c   14080004      MEJIA    JIMENEZ          LUISA
#
#     sexo                 ciudad                    email materias evaluaciones
# 0      M              QUERETARO  tavoferrus_11@email.com      NaN          NaN
# 1      F              QUERETARO    kargi_gogos@email.com      NaN          NaN
# 2      M              QUERETARO     nestoriwh@hotmai.com      NaN          NaN
# 3      M              QUERETARO    cesar_tum-b@email.com      NaN          NaN
# 4      F  SANTIAGO DE QUERETARO                      NaN      NaN          NaN
# ..   ...                    ...                      ...      ...          ...
# 197  NaN                    NaN                      NaN      NaN          NaN
# 198  NaN                    NaN                      NaN      NaN          NaN
# 199  NaN                    NaN                      NaN      NaN          NaN
# 200  NaN                    NaN                      NaN      NaN          NaN
# 201  NaN                    NaN                      NaN      NaN          NaN
#
# [202 rows x 10 columns]

# %%
url = "https://es.wikipedia.org/wiki/ISO_3166-2:MX"

df_html = pd.read_html(url)
print(type(df_html))
df_html
# Out:
# <class 'list'>
# [                                               Estado  \
#  0                                      Aguascalientes
#  1                                     Baja California
#  2                                 Baja California Sur
#  3                                            Campeche
#  4                                             Chiapas
#  5                                           Chihuahua
#  6                                    Ciudad de México
#  7                                            Coahuila
#  8                                              Colima
#  9                                             Durango
#  10                                         Guanajuato
#  11                                           Guerrero
#  12                                            Hidalgo
#  13                                            Jalisco
#  14                                             México
#  15                                          Michoacán
#  16                                            Morelos
#  17                                            Nayarit
#  18                                         Nuevo León
#  19                                             Oaxaca
#  20                                             Puebla
#  21                                          Querétaro
#  22                                       Quintana Roo
#  23                                    San Luis Potosí
#  24                                            Sinaloa
#  25                                             Sonora
#  26                                            Tabasco
#  27                                         Tamaulipas
#  28                                           Tlaxcala
#  29                                           Veracruz
#  30                                            Yucatán
#  31                                          Zacatecas
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                               Variable  \
#  0                                                Ags.
#  1                                                B.C.
#  2                                              B.C.S.
#  3                                               Camp.
#  4                                               Chis.
#  5                                               Chih.
#  6                                             C.D.Mx.
#  7                                               Coah.
#  8                                                Col.
#  9                                                Dgo.
#  10                                               Gto.
#  11                                               Gro.
#  12                                               Hgo.
#  13                                               Jal.
#  14                                      Edo. Méx.[D]​
#  15                                              Mich.
#  16                                               Mor.
#  17                                               Nay.
#  18                                               N.L.
#  19                                               Oax.
#  20                                               Pue.
#  21                                               Qro.
#  22                                        Q. Roo.[F]​
#  23                                             S.L.P.
#  24                                               Sin.
#  25                                               Son.
#  26                                               Tab.
#  27                                             Tamps.
#  28                                              Tlax.
#  29                                               Ver.
#  30                                               Yuc.
#  31                                               Zac.
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                             RENAPO[A]​  \
#  0                                                  AS
#  1                                                  BC
#  2                                                  BS
#  3                                                  CC
#  4                                                  CS
#  5                                                  CH
#  6                                                  DF
#  7                                                  CL
#  8                                                  CM
#  9                                                  DG
#  10                                                 GT
#  11                                                 GR
#  12                                                 HG
#  13                                                 JC
#  14                                                 MC
#  15                                                 MN
#  16                                                 MS
#  17                                                 NT
#  18                                                 NL
#  19                                                 OC
#  20                                                 PL
#  21                                                 QO
#  22                                                 QR
#  23                                                 SP
#  24                                                 SL
#  25                                                 SR
#  26                                                 TC
#  27                                                 TS
#  28                                                 TL
#  29                                                 VZ
#  30                                                 YN
#  31                                                 ZS
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                             Dos letras  \
#  0                                                  AG
#  1                                                  BC
#  2                                                  BS
#  3                                                  CM
#  4                                                  CS
#  5                                                  CH
#  6                                              CX[B]​
#  7                                                  CO
#  8                                                  CL
#  9                                                  DG
#  10                                                 GT
#  11                                                 GR
#  12                                                 HG
#  13                                                 JC
#  14                                             EM[E]​
#  15                                                 MI
#  16                                                 MO
#  17                                                NaN
#  18                                                 NL
#  19                                                 OA
#  20                                                 PU
#  21                                                 QT
#  22                                                 QR
#  23                                                 SL
#  24                                                 SI
#  25                                                 SO
#  26                                                 TB
#  27                                                 TM
#  28                                                 TL
#  29                                                 VE
#  30                                                 YU
#  31                                                 ZA
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                  Completo (ISO 3166-2)
#  0                                              MX-AGU
#  1                                              MX-BCN
#  2                                              MX-BCS
#  3                                              MX-CAM
#  4                                              MX-CHP
#  5                                              MX-CHH
#  6                                          MX-CMX[C]​
#  7                                              MX-COA
#  8                                              MX-COL
#  9                                              MX-DUR
#  10                                             MX-GUA
#  11                                             MX-GRO
#  12                                             MX-HID
#  13                                             MX-JAL
#  14                                             MX-MEX
#  15                                             MX-MIC
#  16                                             MX-MOR
#  17                                             MX-NAY
#  18                                             MX-NLE
#  19                                             MX-OAX
#  20                                             MX-PUE
#  21                                             MX-QUE
#  22                                             MX-ROO
#  23                                             MX-SLP
#  24                                             MX-SIN
#  25                                             MX-SON
#  26                                             MX-TAB
#  27                                             MX-TAM
#  28                                             MX-TLA
#  29                                             MX-VER
#  30                                             MX-YUC
#  31                                             MX-ZAC
#  32  Notas: ↑ Registro Nacional de Población México...  ,
#                          0                                   1
#  0  Control de autoridades  Proyectos Wikimedia  Datos: Q28197]

# %%
print(type(df_html[0]))
df_html[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                Estado  \
# 0                                      Aguascalientes
# 1                                     Baja California
# 2                                 Baja California Sur
# 3                                            Campeche
# 4                                             Chiapas
# 5                                           Chihuahua
# 6                                    Ciudad de México
# 7                                            Coahuila
# 8                                              Colima
# 9                                             Durango
# 10                                         Guanajuato
# 11                                           Guerrero
# 12                                            Hidalgo
# 13                                            Jalisco
# 14                                             México
# 15                                          Michoacán
# 16                                            Morelos
# 17                                            Nayarit
# 18                                         Nuevo León
# 19                                             Oaxaca
# 20                                             Puebla
# 21                                          Querétaro
# 22                                       Quintana Roo
# 23                                    San Luis Potosí
# 24                                            Sinaloa
# 25                                             Sonora
# 26                                            Tabasco
# 27                                         Tamaulipas
# 28                                           Tlaxcala
# 29                                           Veracruz
# 30                                            Yucatán
# 31                                          Zacatecas
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                              Variable  \
# 0                                                Ags.
# 1                                                B.C.
# 2                                              B.C.S.
# 3                                               Camp.
# 4                                               Chis.
# 5                                               Chih.
# 6                                             C.D.Mx.
# 7                                               Coah.
# 8                                                Col.
# 9                                                Dgo.
# 10                                               Gto.
# 11                                               Gro.
# 12                                               Hgo.
# 13                                               Jal.
# 14                                      Edo. Méx.[D]​
# 15                                              Mich.
# 16                                               Mor.
# 17                                               Nay.
# 18                                               N.L.
# 19                                               Oax.
# 20                                               Pue.
# 21                                               Qro.
# 22                                        Q. Roo.[F]​
# 23                                             S.L.P.
# 24                                               Sin.
# 25                                               Son.
# 26                                               Tab.
# 27                                             Tamps.
# 28                                              Tlax.
# 29                                               Ver.
# 30                                               Yuc.
# 31                                               Zac.
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                            RENAPO[A]​  \
# 0                                                  AS
# 1                                                  BC
# 2                                                  BS
# 3                                                  CC
# 4                                                  CS
# 5                                                  CH
# 6                                                  DF
# 7                                                  CL
# 8                                                  CM
# 9                                                  DG
# 10                                                 GT
# 11                                                 GR
# 12                                                 HG
# 13                                                 JC
# 14                                                 MC
# 15                                                 MN
# 16                                                 MS
# 17                                                 NT
# 18                                                 NL
# 19                                                 OC
# 20                                                 PL
# 21                                                 QO
# 22                                                 QR
# 23                                                 SP
# 24                                                 SL
# 25                                                 SR
# 26                                                 TC
# 27                                                 TS
# 28                                                 TL
# 29                                                 VZ
# 30                                                 YN
# 31                                                 ZS
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                            Dos letras  \
# 0                                                  AG
# 1                                                  BC
# 2                                                  BS
# 3                                                  CM
# 4                                                  CS
# 5                                                  CH
# 6                                              CX[B]​
# 7                                                  CO
# 8                                                  CL
# 9                                                  DG
# 10                                                 GT
# 11                                                 GR
# 12                                                 HG
# 13                                                 JC
# 14                                             EM[E]​
# 15                                                 MI
# 16                                                 MO
# 17                                                NaN
# 18                                                 NL
# 19                                                 OA
# 20                                                 PU
# 21                                                 QT
# 22                                                 QR
# 23                                                 SL
# 24                                                 SI
# 25                                                 SO
# 26                                                 TB
# 27                                                 TM
# 28                                                 TL
# 29                                                 VE
# 30                                                 YU
# 31                                                 ZA
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                 Completo (ISO 3166-2)
# 0                                              MX-AGU
# 1                                              MX-BCN
# 2                                              MX-BCS
# 3                                              MX-CAM
# 4                                              MX-CHP
# 5                                              MX-CHH
# 6                                          MX-CMX[C]​
# 7                                              MX-COA
# 8                                              MX-COL
# 9                                              MX-DUR
# 10                                             MX-GUA
# 11                                             MX-GRO
# 12                                             MX-HID
# 13                                             MX-JAL
# 14                                             MX-MEX
# 15                                             MX-MIC
# 16                                             MX-MOR
# 17                                             MX-NAY
# 18                                             MX-NLE
# 19                                             MX-OAX
# 20                                             MX-PUE
# 21                                             MX-QUE
# 22                                             MX-ROO
# 23                                             MX-SLP
# 24                                             MX-SIN
# 25                                             MX-SON
# 26                                             MX-TAB
# 27                                             MX-TAM
# 28                                             MX-TLA
# 29                                             MX-VER
# 30                                             MX-YUC
# 31                                             MX-ZAC
# 32  Notas: ↑ Registro Nacional de Población México...

# %%
print(df_html[0].index)
df_html[0].drop(32, axis=0, inplace=True)

df_html[0]
# Out:
# RangeIndex(start=0, stop=33, step=1)
#                  Estado       Variable RENAPO[A]​ Dos letras  \
# 0        Aguascalientes           Ags.         AS         AG
# 1       Baja California           B.C.         BC         BC
# 2   Baja California Sur         B.C.S.         BS         BS
# 3              Campeche          Camp.         CC         CM
# 4               Chiapas          Chis.         CS         CS
# 5             Chihuahua          Chih.         CH         CH
# 6      Ciudad de México        C.D.Mx.         DF     CX[B]​
# 7              Coahuila          Coah.         CL         CO
# 8                Colima           Col.         CM         CL
# 9               Durango           Dgo.         DG         DG
# 10           Guanajuato           Gto.         GT         GT
# 11             Guerrero           Gro.         GR         GR
# 12              Hidalgo           Hgo.         HG         HG
# 13              Jalisco           Jal.         JC         JC
# 14               México  Edo. Méx.[D]​         MC     EM[E]​
# 15            Michoacán          Mich.         MN         MI
# 16              Morelos           Mor.         MS         MO
# 17              Nayarit           Nay.         NT        NaN
# 18           Nuevo León           N.L.         NL         NL
# 19               Oaxaca           Oax.         OC         OA
# 20               Puebla           Pue.         PL         PU
# 21            Querétaro           Qro.         QO         QT
# 22         Quintana Roo    Q. Roo.[F]​         QR         QR
# 23      San Luis Potosí         S.L.P.         SP         SL
# 24              Sinaloa           Sin.         SL         SI
# 25               Sonora           Son.         SR         SO
# 26              Tabasco           Tab.         TC         TB
# 27           Tamaulipas         Tamps.         TS         TM
# 28             Tlaxcala          Tlax.         TL         TL
# 29             Veracruz           Ver.         VZ         VE
# 30              Yucatán           Yuc.         YN         YU
# 31            Zacatecas           Zac.         ZS         ZA
#
#    Completo (ISO 3166-2)
# 0                 MX-AGU
# 1                 MX-BCN
# 2                 MX-BCS
# 3                 MX-CAM
# 4                 MX-CHP
# 5                 MX-CHH
# 6             MX-CMX[C]​
# 7                 MX-COA
# 8                 MX-COL
# 9                 MX-DUR
# 10                MX-GUA
# 11                MX-GRO
# 12                MX-HID
# 13                MX-JAL
# 14                MX-MEX
# 15                MX-MIC
# 16                MX-MOR
# 17                MX-NAY
# 18                MX-NLE
# 19                MX-OAX
# 20                MX-PUE
# 21                MX-QUE
# 22                MX-ROO
# 23                MX-SLP
# 24                MX-SIN
# 25                MX-SON
# 26                MX-TAB
# 27                MX-TAM
# 28                MX-TLA
# 29                MX-VER
# 30                MX-YUC
# 31                MX-ZAC

# %%
url1 = "https://en.wikipedia.org/w/index.php?title=Solar_power&oldid=1022764142"

df_html2 = pd.read_html(url)
print(type(df_html2))
print("Numero de tablas", len(df_html2))
# Out:
# <class 'list'>
# Numero de tablas 22

# %%
df_html2[2]
# Out:
#                                  Name        Country  Capacity MWp  \
# 0                 Pavagada Solar Park          India          2050
# 1           Tengger Desert Solar Park          China          1547
# 2                   Bhadla Solar Park          India          1515
# 3       Kurnool Ultra Mega Solar Park          India          1000
# 4  Datong Solar Power Top Runner Base          China          1000
# 5          Longyangxia Dam Solar Park          China           850
# 6               Rewa Ultra Mega Solar          India           750
# 7         Kamuthi Solar Power Project          India           648
# 8               Solar Star (I and II)  United States           579
# 9                    Topaz Solar Farm  United States           550
#
#    Generation GWh p.a.  Size km2  \
# 0                  NaN        53
# 1                  NaN        43
# 2                  NaN        40
# 3                  NaN        24
# 4                  NaN       NaN
# 5                  NaN        23
# 6                  NaN       NaN
# 7                  NaN      10.1
# 8               1664.0        13
# 9               1301.0  24.6[74]
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  \
# 0                                               2017
# 1                                               2016
# 2                                               2017
# 3                                               2017
# 4                                               2016
# 5                                               2015
# 6                                               2018
# 7                                               2016
# 8                                               2015
# 9                                               2014
#
#                     Ref
# 0           [2][53][54]
# 1              [55][56]
# 2          [57][58][59]
# 3                  [60]
# 4          [61][62][63]
# 5  [64][65][66][67][68]
# 6                  [69]
# 7              [70][71]
# 8              [72][73]
# 9          [75][76][77]

# %%
i = 0
for dfh in df_html2:
    print(str(i).center(60,"*"))
    dfh.info()
    i = i+1
# Out:
# *****************************0******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes
# *****************************1******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   (Solar Electricity Generation, Year)          16 non-null     object
#  1   (Solar Electricity Generation, Energy (TWh))  16 non-null     object
#  2   (Solar Electricity Generation, % of Total)    16 non-null     object
# dtypes: object(3)
# memory usage: 512.0+ bytes
# *****************************2******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Name                                                                         10 non-null     object
#  1   Country                                                                      10 non-null     object
#  2   Capacity MWp                                                                 10 non-null     int64
#  3   Generation GWh p.a.                                                          2 non-null      float64
#  4   Size km2                                                                     8 non-null      object
#  5   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  10 non-null     int64
#  6   Ref                                                                          10 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 688.0+ bytes
# *****************************3******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           11 non-null     object
#  1   Capacity (MW)  11 non-null     object
#  2   Location       11 non-null     object
#  3   Notes          11 non-null     object
# dtypes: object(4)
# memory usage: 480.0+ bytes
# *****************************4******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# *****************************5******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# *****************************6******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes
# *****************************7******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vteSolar energy    24 non-null     object
#  1   vteSolar energy.1  24 non-null     object
#  2   vteSolar energy.2  2 non-null      object
# dtypes: object(3)
# memory usage: 704.0+ bytes
# *****************************8******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6 non-null      object
#  1   1       6 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes
# *****************************9******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************10*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       8 non-null      object
#  1   1       8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# *****************************11*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   vteSolar power by country    8 non-null      object
#  1   vteSolar power by country.1  8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# *****************************12*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vtePhotovoltaics    22 non-null     object
#  1   vtePhotovoltaics.1  22 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes
# *****************************13*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************14*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************15*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
#  1   1       5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes
# *****************************16*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************17*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# *****************************18*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   vteElectricity delivery    11 non-null     object
#  1   vteElectricity delivery.1  11 non-null     object
#  2   vteElectricity delivery.2  1 non-null      object
# dtypes: object(3)
# memory usage: 392.0+ bytes
# *****************************19*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# *****************************20*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   vteRenewable energy by country and territory    9 non-null      object
#  1   vteRenewable energy by country and territory.1  9 non-null      object
# dtypes: object(2)
# memory usage: 272.0+ bytes
# *****************************21*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes

# %%
url= 'http://ingenieria.aragon.unam.mx/ico/alumnos/examenes_extraordinarios.rb'
df_html3 = pd.read_html(url)
print(type(df_html3))
df_html2
print("Numero de elementos en DF", len(df_html3))

#Al no encontrar tablas en la pagina, marca un error
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[59], line 2
#       1 url= 'http://ingenieria.aragon.unam.mx/ico/alumnos/examenes_extraordinarios.rb'
# ----> 2 df_html3 = pd.read_html(url)
#       3 print(type(df_html3))
#       4 df_html2
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:982, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     980 retained = None
#     981 for flav in flavor:
# --> 982     parser = _parser_dispatch(flav)
#     983     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     985     try:
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:931, in _parser_dispatch(flavor)
#     929 if flavor in ("bs4", "html5lib"):
#     930     if not _HAS_HTML5LIB:
# --> 931         raise ImportError("html5lib not found, please install it")
#     932     if not _HAS_BS4:
#     933         raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %% [markdown]
# # TAREA
#
# #### Generar un DF con una o varias tablas de una URL diferente a las vistas en la sesión

# %%
urlA = "https://es.wikipedia.org/wiki/Love_Live!_Sunshine!!"

DF_Aqours = pd.read_html(urlA)
print(type(DF_Aqours))
print("Numero de tablas", len(DF_Aqours))
# Out:
# <class 'list'>
# Numero de tablas 4

# %%
DF_Aqours[1]
# Out:
#     Núm.                                             Título  \
# 0      1        «¡Quiero brillar!» «Kagayakitai!!» (輝きたい!!)
# 1      2  «¡Atrapa a la recién llegada!» «Tenkōsei o Tsu...
# 2      3       «¡Primer paso!» «Fāsuto Suteppu» (ファーストステップ)
# 3      4   «Sus sentimientos» «Futari no Kimochi» (ふたりのキモチ)
# 4      5          «Yohane desciende» «Yohane Daten» (ヨハネ堕天)
# 5      6     «Hagamos un video» «Pī Bui o Tsukurō» (PVを作ろう)
# 6      7                                            «Tokyo»
# 7      8  «¿No estás frustrada?» «Kuyashikunai no?» (くやし...
# 8      9    «Jóvenes soñadoras» «Mijuku Dorīma» (未熟DREAMER)
# 9     10  «Tenemos Shinystofado» «Shai-ni Hajimemashita»...
# 10    11       «Amistad a la vista» «Yūjō Yōsorō» (友情ヨーソロー)
# 11    12  «Hora de emprender el vuelo» «Habataki no Toki...
# 12    13               «Sunshine!!» «Sanshain!!» (サンシャイン!!)
#
#             Fecha de emisión
# 0         2 de julio de 2016
# 1         9 de julio de 2016
# 2        16 de julio de 2016
# 3        23 de julio de 2016
# 4        30 de julio de 2016
# 5        6 de agosto de 2016
# 6       13 de agosto de 2016
# 7       20 de agosto de 2016
# 8       27 de agosto de 2016
# 9    3 de septiembre de 2016
# 10  10 de septiembre de 2016
# 11  17 de septiembre de 2016
# 12  24 de septiembre de 2016

# %% [markdown]
# #### Generar un DF de alumnos o alumnas de la tabla alumnos de la base bdcolegio02 del servidor bd.arcelia.net

# %%
from sqlalchemy import create_engine

us = 'fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegio02'
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd, url, puerto, bd, auth)

# %%
conn = create_engine(str_conn)
conn
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password)

# %%
sql = '''SELECT * FROM alumnos WHERE sexo = 'F' '''

Alumnas = pd.read_sql_query(sql = sql, con = conn)

# %%
Alumnas
# Out:
#     clave_alu clave_admin ap_paterno ap_materno             nombre sexo  \
# 0    11030172        4812   BORBOLLA      RAMOS            ARGELIA    F
# 1    11030173        4849     CASTRO    MANCERA      KARLA MARIANA    F
# 2    11030207        4808    AGUILAR  ZAMARRIPA    MICHELLE IVONNE    F
# 3    11030218        4717     FLORES      NAMUR     MARIA FERNANDA    F
# 4    11030254        4724   GONZALEZ       DIAZ  CLAUDIA ALEJANDRA    F
# ..        ...         ...        ...        ...                ...  ...
# 278  11080201                   SOTO      ELIAS     PALOMA DENISSE    F
# 279  11080202                 VALLES      RAMOS            MARIANA    F
# 280  11080205                  BADUY     VALDEZ      KENNIA ASENET    F
# 281  11080208               BECERRIL     HUERTA            MARIANA    F
# 282  11080209        NULL    MORALES    CARMONA      KARLA MARIANA    F
#
#                    curp  peso  estatura                           direccion  \
# 0                        52.0      1.60                 CLUB CAMPESTRE #867
# 1                         0.0      0.00              LAGO DE XOCHIMILCO 666
# 2    AUZM910928MQTGMC08  47.5      1.71                        ECOLOGIA 689
# 3    FONF910110MQTLMR00  58.0      1.62                        BOTANICA#609
# 4    GODC910202MDFNZL01  60.0      1.63   FRAY ANTONIO MARGIL DE JESUS  #96
# ..                  ...   ...       ...                                 ...
# 278  SOEP921030MQTTLL03  52.0      1.51          70 DE NOVIEMBRE NO. 7 PTE.
# 279  VARM930602MCHLMR08  62.0      1.66                   MARIO GONZALEZ #0
# 280  BAKV931111MQTDLN18  59.0      1.60  FRAY FRANCISCO DE LOS ANGELES #766
# 281  BEHM930222MQTCRR06  52.0      1.59                PASEO DE SOFIA # 709
# 282                       NaN       NaN                                None
#
#                          colonia     cp                 ciudad  id_estado  \
# 0                 CLUB CAMPESTRE  26190              QUERETARO         22
# 1             LOMAS DE SAN PABLO  26130  SANTIAGO DE QUERETARO         22
# 2                    TECNOLOGICO  26158              QUERETARO         22
# 3                    TECNOLOGICO  26158              QUERETARO         22
# 4       LOS MOLINOS 2DA. SECCION  26150  SANTIAGO DE QUERETARO         22
# ..                           ...    ...                    ...        ...
# 278   CENTRO SANTA ROSA JAUREGUI  26220              QUERETARO         22
# 279  FRACCIONAMIENTO VILLA CORZO  32980      SAN JOSE ITURBIDE         12
# 280          QUINTAS DEL MARQUEZ  26042              QUERETARO         22
# 281                       TEJEDA  26904              QUERETARO         22
# 282                         None   None                   None         18
#
#                   delegacion       telefono        celular  \
# 0                  QUERETARO     4455497989     9612497989
# 1                  QUERETARO
# 2                  QUERETARO
# 3                  QUERETARO     4458585556     9618285226
# 4         EPIGMENIO GONZALEZ  0444458170558  0449618170258
# ..                       ...            ...            ...
# 278  SANTA ROSA JAUREGUI QRO  0444458775868  0449618772868
# 279        SAN JOSE ITURBIDE     4191089618     4191089618
# 280                QUERETARO     4451544548     9611244548
# 281              CORREGIDORA     4458448574     9618448574
# 282                     None           None           None
#
#                            email status_alu              fedita
# 0         argi_gogos@miemail.com         AC 2021-11-21 20:08:41
# 1                                        AC 2021-11-07 22:02:27
# 2                                        AC 2021-10-04 20:53:54
# 3            maferfn@miemail.com         AC 2021-09-17 20:30:41
# 4        jlgg1504@telmart.com.mx         AC 2021-09-04 19:40:34
# ..                           ...        ...                 ...
# 278  chiquis_palomit@miemail.com         AS 2023-03-12 16:41:30
# 279   mariana_020693@miemail.com         AS 2023-03-10 14:00:21
# 280         keny_625@miemail.com         AS 2023-03-12 19:45:44
# 281     mane_chiquis@miemail.com         AS 2023-03-11 19:46:25
# 282                         None         AS 2023-04-15 20:48:37
#
# [283 rows x 20 columns]
